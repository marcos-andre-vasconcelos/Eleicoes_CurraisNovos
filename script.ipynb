# %%
import pandas as pd

# %%
caminho = 'C:\\Users\\marco\\Documents\\Projetos Pessoais\\Arquivos\\Eleições Currais Novos\\votacao_candidato_munzona_2020_RN.csv'

df = pd.read_csv(caminho, sep=';', encoding='Latin 1')

# %%
colunas = df[['ANO_ELEICAO', 
              'CD_TIPO_ELEICAO',
              'NM_TIPO_ELEICAO',
              'NR_TURNO', 
              'CD_ELEICAO',
              'DS_ELEICAO',
              'DT_ELEICAO',
              'SG_UF', 
              'CD_MUNICIPIO', 
              'NM_MUNICIPIO', 
              'NR_ZONA',
              'CD_CARGO',
              'DS_CARGO', 
              'SQ_CANDIDATO',
              'NR_CANDIDATO',
              'NM_CANDIDATO', 
              'NM_URNA_CANDIDATO', 
              'NR_PARTIDO', 
              'NM_PARTIDO',
              'SG_PARTIDO',
              'QT_VOTOS_NOMINAIS', 
              'QT_VOTOS_NOMINAIS_VALIDOS']]

# %%
colunas
# Out:
#        ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO  \
# 0             2020                2  Eleição Ordinária         1         426
# 1             2020                2  Eleição Ordinária         1         426
# 2             2020                2  Eleição Ordinária         1         426
# 3             2020                2  Eleição Ordinária         1         426
# 4             2020                2  Eleição Ordinária         1         426
# ...            ...              ...                ...       ...         ...
# 12681         2020                2  Eleição Ordinária         1         426
# 12682         2020                2  Eleição Ordinária         1         426
# 12683         2020                2  Eleição Ordinária         1         426
# 12684         2020                2  Eleição Ordinária         1         426
# 12685         2020                2  Eleição Ordinária         1         426
#
# ...

# %%
#colunas['NM_PARTIDO'] = colunas['NM_PARTIDO'].str.upper()
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_10976\526697521.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colunas['NM_PARTIDO'] = colunas['NM_PARTIDO'].str.upper()
